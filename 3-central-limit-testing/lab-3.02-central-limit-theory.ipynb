# %% [markdown]
# # Lab 3.02 - The Central Limit Theorem

# %%
# Package Imports
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Data Frame
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt                     # Basic visualisation
from statsmodels.graphics.mosaicplot import mosaic  # Mosaic diagram
import seaborn as sns                               # Advanced data visualisation

# %% [markdown]
# ## Exercise 1 - Cholesterol
#
# A health survey between 1988 and 1994 indicated that the mean cholesterol value for women between the age of 20 and 29 was 183 mg/dl, with a standard deviation equal to 36. We now take a random sample of 81 women.
#
# 1. Plot the probability distribution of the sample mean $\overline{x}$.
# 2. What is the probability of the sample mean being $\overline{x} < 185$? (Answer ≈ 69,1%)
# 3. What is the probability of $175 < \overline{x} < 185$ (Answer ≈ 66,9%)
# 4. What is the probability of $\overline{x} > 190$ (Answer ≈ 4,0%)

# %%
mu = 183
std = 36
n = 81
stderr = std / np.sqrt(n)

x = np.linspace(mu - 4 * stderr, mu + 4 * stderr, 201)
y = stats.norm.pdf(x, loc=mu, scale=stderr)
plt.plot(x, y)
plt.axvline(mu, color='red', linestyle='--')
print(stats.norm.cdf(185, loc=mu, scale=stderr))
print(stats.norm.cdf(185, loc=mu, scale=stderr) - stats.norm.cdf(175, loc=mu, scale=stderr))
print(1- stats.norm.cdf(190, loc=mu, scale=stderr))

plt.axvline(175, color='orange', linestyle='--')
plt.axvline(185, color='blue', linestyle='--')
plt.axvline(190, color='green', linestyle='--')
# Out:
# 0.6914624612740131
# 0.6687123293258339
# 0.040059156863817114

# %%
pop_mean = 183
pop_std = 36
n = 81
stderr = pop_std / np.sqrt(n)

xvals = np.linspace(pop_mean - 4 * stderr, pop_mean + 4 * stderr, 201)
yvals = stats.norm.pdf(xvals, loc=pop_mean, scale=stderr)
plt.plot(xvals, yvals)
plt.axvline(pop_mean, color='red', linestyle='--')
print(f"P(M < 185) = {stats.norm.cdf(185, loc=pop_mean, scale=stderr):.4f}")
print(f"P(175 < M < 185) = {stats.norm.cdf(185, loc=pop_mean, scale=stderr) - stats.norm.cdf(175, loc=pop_mean, scale=stderr):.4f}")
print(f"P(M > 190) = {1 - stats.norm.cdf(190, loc=pop_mean, scale=stderr):.4f}")

plt.axvline(175, color='orange', linestyle='--')
plt.axvline(185, color='blue', linestyle='--')
plt.axvline(190, color='green', linestyle='--')
# Out:
# P(M < 185) = 0.6915
# P(175 < M < 185) = 0.6687
# P(M > 190) = 0.0401

# %% [markdown]
# ## Exercise 2
#
# A random sample of 64 is drawn from a population with unknown distribution. However, the expectation and standard deviation of the population are known: $\mu = 20$ and $\sigma = 16$.
#
# 1. Plot the probability distribution of the sample mean.
# 2. Calculate the z-score for $\overline{x_1} = 15.5$
# 3. Calculate the z-score for $\overline{x_2} = 23$
# 4. Determine the probability that 16 < $\overline{x}$ < 22 (Answer ≈ 81.9%)

# %%
sigma = 16
mu = 20
n = 64

err = sigma / np.sqrt(n)

x = np.linspace(mu - 4 * err, mu + 4 * err, 201)
y = stats.norm.pdf(x, loc=mu, scale=err)
plt.plot(x, y)
plt.axvline(mu, color='red', linestyle='--')
plt.axvline(22, color='green', linestyle='--')
plt.axvline(16, color='blue', linestyle='--')

print((15.5-mu) / sigma)
print((23-mu) / sigma)



print(stats.norm.cdf(22, loc=mu, scale=err) - stats.norm.cdf(16, loc=mu, scale=err))
# Out:
# -0.28125
# 0.1875
# 0.8185946141203637

# %% [markdown]
# ## Exercise 3
#
# When students write in their bachelor thesis proposal that they want to conduct a survey, we usually try to dissuade them from doing so. With what you have learned about sampling and the central limit theorem, can you think of some reasons why we do this?
