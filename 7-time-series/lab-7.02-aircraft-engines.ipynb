# %% [markdown]
# # Lab 7.02 - Time series analysis

# %%
# Package imports
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Data Frame
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt                     # Basic visualisation
from statsmodels.graphics.mosaicplot import mosaic  # Mosaic diagram
import seaborn as sns                               # Advanced data visualisation

# %% [markdown]
# ## Exercise 2 - aircraft engines
#
# You have been assigned to forecast the number of aircraft engines ordered each month from an engine manufacturing company. At the end of February, the
# forecast is that 100 engines will be ordered during April.
# Then during March, 120 engines are actually ordered.
# Using $\alpha$ = 0.3, determine a forecast (at the end of March) for the number of orders placed during April and during May. Use simple exponential
# smoothing.
# These are the appropriate formulae
# Level:
# $L_t = \alpha Y_t + (1 - \alpha) L_{t-1}$
# Forecast:
# $F_{t+k} = L_t$

# %%
alpha = 0.3
L_feb = 100  # Forecast voor april gemaakt eind februari
Y_mrt = 120  # Werkelijke orders in maart

# Stap 1: Bereken het niveau aan het einde van maart (Lt)
# Formule: Lt = alpha * Yt + (1 - alpha) * Lt-1
L_mrt = alpha * Y_mrt + (1 - alpha) * L_feb

# Stap 2: Bepaal de forecast voor april en mei
# Formule: Ft+k = Lt
forecast_apr = L_mrt
forecast_mei = L_mrt

print(f"Niveau aan het einde van maart (L_t): {L_mrt}")
print(f"Forecast voor april: {forecast_apr}")
print(f"Forecast voor mei: {forecast_mei}")
# Out:
# Niveau aan het einde van maart (L_t): 106.0
# Forecast voor april: 106.0
# Forecast voor mei: 106.0

# %% [markdown]
# ## Source
# Business Analytics Data Analysis & Decision Making
